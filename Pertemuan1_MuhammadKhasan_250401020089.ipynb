# %% [markdown]
# Nama  : Muhammad Khasan Zubaeri
#
# NIM   : 250401020089
#
# Kelas : IF403

# %%
# ==========================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ==========================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variable dan tipe data dasar
nama      = "Mahasiswa Informatika"     # String
angkatan  = 2025                        # Integer
ipk       = 3.66                        # Float
aktif     = True                        # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Mahasiswa Informatika
# Angkatan  : 2025
# IPK       : 3.66
# Aktif     : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub" ]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Muhammad Khasan Zubaeri", "Informatika", "2025")
print(hasil)
# Out:
# Hai! Saya Muhammad Khasan Zubaeri dari Informatika, angkatan 2025.

# %% [markdown]
# Kesimpulan terhadap kegiatan praktikum:
#
# Praktikum mempelajari dan mengimplementasikan mengenai dasar-dasar python seperti penggunaan print, memperkenalkan variabel dan tipe data, list dan perulangan dan fungsi sederhana untuk menampilkan sebuah data.
#
# temuan utama dari hasil praktikum bahwa sintaks pada python cukup mudah dipahami untuk pemula. dari beberapa baris kode sederhana kita dapat menampilkan informasi dan mengelola data sederhana.
#
# keterbatasan : materi yang dipelajari masih sangat sederhana sehingga muncul pertanyaan tentang cara mengolah dan menganalisis data menggunakan Python pada tingkat lanjut.
