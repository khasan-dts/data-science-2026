# %% [markdown]
# Nama : Muhammad Khasan Zubaeri
#
# NIM : 250401020089
#
# Kelas : IF403

# %%
# ========================================
# PIPELINE DATA CLEANING — HOUSING DATASET
# ========================================

import pandas as pd
import numpy as np
from scipy.stats.mstats import winsorize

# Muat Dataset
import pandas as pd
df = pd.read_csv('housing_dirty.csv')

print('Dataset berhasil dimuat!')
# Out:
# Dataset berhasil dimuat!

# %%
# Eksplorasi Awal
print("\n==== Informasi Dataset ====")
print(df.info())

print("\n==== Deskripsi Dataset ====")
print(df.describe())

print("\n==== Jumlah Missing Value per kolom ====")
print(df.isnull().sum())
# Out:
# ==== Informasi Dataset ====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            130 non-null    int64
#  1   luas_m2       112 non-null    float64
#  2   harga_juta    113 non-null    float64
#  3   kota          130 non-null    object
#  4   kamar         120 non-null    float64
#  5   tahun_bangun  130 non-null    int64
#  6   kondisi       130 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 7.2+ KB
# None
#
# ==== Deskripsi Dataset ====
#                id      luas_m2    harga_juta       kamar  tahun_bangun
# count  130.000000   112.000000  1.130000e+02  120.000000    130.000000
# mean    65.500000   267.627679  8.856325e+05    3.433333   2062.638462
# std     37.671829   885.664181  9.407144e+06    1.776283    701.684043
# ...

# %%
# Hapus Baris Duplikat
df.drop_duplicates(inplace=True)
print('Setelah hapus duplikat:', df.shape)
# Out:
# Setelah hapus duplikat: (130, 7)

# %%
# Normalisasi String

df['kota'] = df['kota'].str.strip().str.title()
df['kondisi'] = df['kondisi'].str.strip().str.lower()

print("\nNormaliasi string telah dilakukan")
# Out:
# Normaliasi string telah dilakukan.

# %%
# Imputasi Missing Values

df['luas_m2'] = df['luas_m2'].fillna(df['luas_m2'].median())
df['harga_juta'] = df['harga_juta'].fillna(df['harga_juta'].median())
df['kamar'] = df['kamar'].fillna(df['kamar'].mode()[0])

print("\nImputasi Missing Values telah dilakukan")
# Out:
# Imputasi Missing Values telah dilakukan

# %%
# Tangani Outlier dengan (IQR Fence)
for col in ['harga_juta', 'luas_m2', 'tahun_bangun']:
    Q1, Q3 = df[col].quantile([0.25, 0.75])
    IQR = Q3 - Q1
    df[col] = df[col].clip(Q1 - 1.5*IQR, Q3 + 1.5*IQR)

print("\nPenanganan Outlier dengan (IQR Fence) telah dilakukan")
# Out:
# Penanganan Outlier dengan (IQR Fence) telah dilakukan

# %%
# Validasi dan Ekspor
assert df.isnull().sum().sum() == 0, 'Masih ada missing!'
assert df.duplicated().sum() == 0, 'Masih ada duplikat!'
print('Shape akhir:', df.shape)
df.to_csv('housing_clean.csv', index=False)
print('Dataset bersih tersimpan!')
# Out:
# Shape akhir: (130, 7)
# Dataset bersih tersimpan!

# %%
# Akses API JSONPlaceholder
import requests

url = 'https://jsonplaceholder.typicode.com/posts'
response = requests.get(url)

# Simpan ke dalam DataFrame
data = response.json()
df = pd.DataFrame(data)

print(df)
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# ...

# %% [markdown]
# **Kesimpulan terhadap kegiatan praktikum:**
#
# Praktikum mempelajari proses data cleaning, mulai dari memuat dataset, mengecek kondisi data, menghapus data duplikat, menormalkan format teks, mengatasi data yang hilang (missing values), menangani outlier, serta menyimpan hasil data yang sudah bersih. Selain itu juga mempelajari cara mengambil data dari JSONPlaceholder menggunakan library requests dan menyimpannya ke dalam DataFrame.
#
# Temuan utama dari hasil praktikum adalah kualitas data sangat berpengaruh terhadap hasil analisis sehingga perlu adanya proses untuk pembersihan data melalui berbagai cara seperti menghapus data duplikat dan mengatasi data yang hilang.
#
# keterbatasan : proses pembersihan data masih sebatas menghapus data duplikat dan mengatasi data yang hilang sehingga muncul pertanyaan bagaimana cara menentukan metode penanganan missing value yang tepat agar tidak mepengaruhi hasil analisis secara signifikan.
